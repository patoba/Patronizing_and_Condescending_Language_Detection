# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import bag_of_words, sentiment_analysis

# %%
results_bag, tiempos_bag, df_models_bag, best_model_bag = bag_of_words()
# Out:
# all_words lemmatizator bag_of_words logistic_regression
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# /home/pato/EV/ML/lib/python3.6/site-packages/sklearn/model_selection/_search.py:925: UserWarning: One or more of the test scores are non-finite: [       nan 0.39286143        nan 0.32908496]
#   category=UserWarning
# all_words lemmatizator bag_of_words knn
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# all_words lemmatizator bag_of_words svm
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-ca8ac400be3c> in <module>
# ----> 1 results_bag, tiempos_bag, df_models_bag, best_model_bag = bag_of_words()
#
# ~/escuela/septimo semestre/nlp/Patronizing_and_Condescending_Language_Detection/main.py in bag_of_words(file_url)
#      27 def bag_of_words(file_url = file_url):
#      28     X, y = read_csv(file_url)
# ---> 29     return process_bag_of_words(X, y)
#      30
#      31 def sentiment_analysis(file_url = file_url):
#
# ~/escuela/septimo semestre/nlp/Patronizing_and_Condescending_Language_Detection/model_selection/processing.py in process_bag_of_words(X, y, n_jobs)
#      38                                 n_jobs = n_jobs,
#      39                                 verbose = 2)
# ---> 40                     grid.fit(X_train, y_train)
#      41                     tiempo_total = time() - tiempo_inicio
#      42                     tiempos[name_preprocessor, name_base, name_modeling, name_classifier] = tiempo_total
#
# ~/EV/ML/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/EV/ML/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~/EV/ML/lib/python3.6/site-packages/imblearn/pipeline.py in fit(self, X, y, **fit_params)
#     266         """
#     267         fit_params_steps = self._check_fit_params(**fit_params)
# --> 268         Xt, yt = self._fit(X, y, **fit_params_steps)
#     269         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     270             if self._final_estimator != "passthrough":
#
# ~/EV/ML/lib/python3.6/site-packages/imblearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     221                     message_clsname="Pipeline",
#     222                     message=self._log_message(step_idx),
# --> 223                     **fit_params_steps[name],
#     224                 )
#     225             elif hasattr(cloned_transformer, "fit_resample"):
#
# ~/EV/ML/lib/python3.6/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/EV/ML/lib/python3.6/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     752     with _print_elapsed_time(message_clsname, message):
#     753         if hasattr(transformer, 'fit_transform'):
# --> 754             res = transformer.fit_transform(X, y, **fit_params)
#     755         else:
#     756             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/EV/ML/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
# --> 702             return self.fit(X, y, **fit_params).transform(X)
#     703
#     704
#
# ~/escuela/septimo semestre/nlp/Patronizing_and_Condescending_Language_Detection/preprocessing/lexical_base.py in transform(self, X, y)
#      13          check_is_fitted(self)
#      14          words = X.copy()
# ---> 15          words = words.apply(lambda line: [self.transf_f_(w) for w in line])
#      16          return words
#      17
#
# ~/EV/ML/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/escuela/septimo semestre/nlp/Patronizing_and_Condescending_Language_Detection/preprocessing/lexical_base.py in <lambda>(line)
#      13          check_is_fitted(self)
#      14          words = X.copy()
# ---> 15          words = words.apply(lambda line: [self.transf_f_(w) for w in line])
#      16          return words
#      17
#
# ~/escuela/septimo semestre/nlp/Patronizing_and_Condescending_Language_Detection/preprocessing/lexical_base.py in <listcomp>(.0)
#      13          check_is_fitted(self)
#      14          words = X.copy()
# ---> 15          words = words.apply(lambda line: [self.transf_f_(w) for w in line])
#      16          return words
#      17
#
# ~/EV/ML/lib/python3.6/site-packages/nltk/stem/wordnet.py in lemmatize(self, word, pos)
#      36
#      37     def lemmatize(self, word, pos=NOUN):
# ---> 38         lemmas = wordnet._morphy(word, pos)
#      39         return min(lemmas, key=len) if lemmas else word
#      40
#
# ~/EV/ML/lib/python3.6/site-packages/nltk/corpus/reader/wordnet.py in _morphy(self, form, pos, check_exceptions)
#    1943
#    1944         # 1. Apply rules once to the input to get y1, y2, y3, etc.
# -> 1945         forms = apply_rules([form])
#    1946
#    1947         # 2. Return all that are in the database (and check the original too)
#
# ~/EV/ML/lib/python3.6/site-packages/nltk/corpus/reader/wordnet.py in apply_rules(forms)
#    1921             return [
#    1922                 form[: -len(old)] + new
# -> 1923                 for form in forms
#    1924                 for old, new in substitutions
#    1925                 if form.endswith(old)
#
# ~/EV/ML/lib/python3.6/site-packages/nltk/corpus/reader/wordnet.py in <listcomp>(.0)
#    1922                 form[: -len(old)] + new
#    1923                 for form in forms
# -> 1924                 for old, new in substitutions
#    1925                 if form.endswith(old)
#    1926             ]
#
# KeyboardInterrupt:
